# %%
import sqlite3
import pandas as pd

bias_df = pd.read_csv("allsides-ranking.csv")

db_path = "data/news_articles.db"   # update if needed
conn = sqlite3.connect(db_path)

# %%
conn.execute("ALTER TABLE article_urls ADD COLUMN bias TEXT;")

# %%
cur = conn.cursor()

for _, row in bias_df.iterrows():
    cur.execute("""
        UPDATE article_urls
        SET bias = ?
        WHERE lower(outlet_name) = lower(?)
    """, (row["bias"], row["outlet"]))

conn.commit()

# %%
# article_urls
print("article_urls")
display(pd.read_sql("PRAGMA table_info(article_urls);", conn))

# article_contents
print("article_contents")
display(pd.read_sql("PRAGMA table_info(article_contents);", conn))
# Out:
# === article_urls ===
#    cid         name  type  notnull dflt_value  pk
# 0    0         uuid  TEXT        0       None   0
# 1    1          url  TEXT        0       None   0
# 2    2  outlet_name  TEXT        0       None   0
# 3    3         bias  TEXT        0       None   0
# === article_contents ===
#    cid                  name  type  notnull dflt_value  pk
# 0    0                  uuid  TEXT        0       None   0
# 1    1                  date  TEXT        0       None   0
# 2    2               content  TEXT        0       None   0
# 3    3  content_preprocessed  TEXT        0       None   0
# 4    4              language  TEXT        0       None   0

# %%
# filter to number of articles per year to find viable outlets

query_long = """
SELECT
  u.outlet_name,
  COALESCE(u.bias, 'Unknown') AS bias,
  SUBSTR(c.date,1,4) AS year,
  COUNT(*) AS n
FROM article_urls u
JOIN article_contents c
  ON u.uuid = c.uuid
WHERE c.date IS NOT NULL
  AND c.date >= '2015-01-01'
  AND c.date <  '2022-01-01'
GROUP BY u.outlet_name, COALESCE(u.bias,'Unknown'), SUBSTR(c.date,1,4);
"""
df_long = pd.read_sql(query_long, conn)

# Pivot to years as columns
df_pivot = (df_long
            .pivot_table(index=['outlet_name','bias'],
                         columns='year', values='n',
                         fill_value=0)
            .reset_index())
year_cols = [c for c in df_pivot.columns if c.isdigit()]
df_pivot[year_cols] = df_pivot[year_cols].astype(int)

# %%
df_pivot = df_pivot.sort_values('2021', ascending=False)
df_pivot.head(20)
# Out:
# year             outlet_name        bias  2015  2016  2017  2018  2019  2020  \
# 19                  Newsweek        Left  2180  2843  3964  4576  4018  5210
# 4             Breitbart News       Right  1684  2396  2091  2495  3133  4493
# 18                   Newsmax     Unknown  1202   789   957  1078   395  1004
# 17             New York Post     Unknown   633   717   847  2209  1777  3118
# 7                       CNBC      Center   880   801  1348  1532  2040  3229
# 9                Daily Beast        Left  1936  2023  1623  2219  2680  3887
# 42          Washington Times  Lean Right  1145   759  1672  1547  1345  1870
# 29           The Epoch Times  Lean Right   128   177    27    82   638   166
# 34       The Washington Post     Unknown  1295  1375  1426  1019   824   900
# 40                       Vox        Left  7824  4620  4332  3368  2083  3164
# 26             Rolling Stone     Unknown  1513  2183  2108  1492  2199  2139
# 39                      Vice        Left  2076  2484  2323  1567  1006   972
# 0                   ABC News     Unknown    16     7    13    42   240   541
# 41       Wall Street Journal     Unknown  2362  2920  1462  1585  2088  1942
# 14                  HuffPost        Left  3887  4486  3735  1514  1774  2447
# 25                   Reuters      Center   297  1013  1210  1662  1841  3645
# 27                     Slate        Left  1278  1243   962  1200   904   873
# 33            The New Yorker        Left  1260  1118  1158  1114  1052  1104
# 13                     Heavy     Unknown   219   253   385   256   482   751
# 37                  Townhall       Right    61   100   165   133   147   298
# 2              Bizpac Review       Right   209   244   309   297   414   534
# 1                   BBC News      Center  4658  6141  1715  3286  2288  1171
# 30        The Gateway Pundit       Right   104   110   157   153   189   479
# 21                  PJ Media       Right   977  1484   937  1035   700   362
# 15                     MSNBC        Left  1591  1068   157   164   316   191
# 24                 Red State       Right   453   903   665   822   901   799
# 43                 ZeroHedge  Lean Right   289   359   524    66     0   165
# 20    Orange County Register  Lean Right   246   256   225   228   222   176
# 31              The Guardian   Lean Left   197   237   232   253   296   338
# 5           Business Insider      Center    33    69    74    47    43   319
# 16           National Review       Right   177   123   139   107   114   163
# 10           FiveThirtyEight      Center   179   225   214   187   243   195
# 35       The Western Journal       Right     0     0     0   579   250   158
# 11                    Forbes      Center    59    41    66   122   113   209
# 38                 USA TODAY      Center   249   290   539   530   499   483
# 6                   CBS News   Lean Left   273   268   290   323   269   320
# 12                  Fox News     Unknown   343    44   132   139   163  1151
# 32        The New York Times     Unknown   117    92    42    40    30    16
# 23                  Politico   Lean Left    28   188    19     8    18    27
# 36                  TheBlaze     Unknown   388    48   138   157   116    43
# 22                     Patch     Unknown     0     0     1     0     2     1
# 3                  Bloomberg   Lean Left     2     1     0     1     0     1
# 8                        CNN     Unknown  2391     0     0     0     0     0
# 28          The Daily Caller       Right   421   556   513     1     1     0
#
# year  2021
# 19    9547
# 4     6095
# 18    5288
# 17    3855
# 7     3646
# 9     2706
# 42    2525
# 29    2413
# 34    2310
# 40    2010
# 26    1963
# 39    1858
# 0     1796
# 41    1583
# 14    1580
# 25    1543
# 27    1407
# 33    1369
# 13    1236
# 37    1229
# 2     1164
# 1     1116
# 30    1034
# 21     968
# 15     880
# 24     848
# 43     800
# 20     622
# 31     500
# 5      496
# 16     411
# 10     364
# 35     363
# 11     357
# 38     355
# 6      325
# 12      94
# 32      28
# 23      26
# 36       7
# 22       4
# 3        1
# 8        0
# 28       0

# %%
# Filter to 3 outlets per political bias

OUTLETS = (
    "Newsweek",
    "The Washington Post",
    "HuffPost",
    "Breitbart News",
    "New York Post",
    "Washington Times",
    "CNBC",
    "Reuters",
    "BBC News"
)

query = f"""
SELECT 
    u.outlet_name,
    u.bias,
    c.date,
    c.content,
    c.content_preprocessed
FROM article_urls u
JOIN article_contents c
    ON u.uuid = c.uuid
WHERE c.date IS NOT NULL
  AND c.date >= '2015-01-01'
  AND c.date <  '2022-01-01'
  AND u.outlet_name IN ({','.join(['?']*len(OUTLETS))});
"""

LRC_articles = pd.read_sql(query, conn, params=list(OUTLETS))
LRC_articles.head()
# Out:
#   outlet_name  bias        date  \
# 0    HuffPost  Left  2017-03-13
# 1    HuffPost  Left  2018-02-28
# 2    HuffPost  Left  2018-09-24
# 3    HuffPost  Left  2019-03-06
# 4    HuffPost  Left  2015-02-10
#
#                                              content  \
# 0  The term “integrative therapies” describes the...
# 1  “I had people ― wealthy, billionaires ― callin...
# 2  Le chef du Parti québécois, Jean-François Lisé...
# 3  James Leynse via Getty Images\nWhen is addicti...
# 4  AMC\nFor Canadian actor Michael Mando, lightni...
#
#                                 content_preprocessed
# 0  The term “integrative therapies” describes the...
# 1  “I had people ― wealthy, billionaires ― callin...
# 2  Le chef du Parti québécois, Jean-François Lisé...
# 3  James Leynse via Getty Images\nWhen is addicti...
# 4  AMC\nFor Canadian actor Michael Mando, lightni...

# %%
LRC_articles.isna().sum()
# Out:
# outlet_name                 0
# bias                    22305
# date                        0
# content                  4634
# content_preprocessed        0
# dtype: int64

# %%
LRC_articles[LRC_articles["bias"].isna()]["outlet_name"].unique()
# Out:
# array(['The Washington Post', 'New York Post'], dtype=object)

# %%
# Update political bias where missing due to naming convention (The Washington Post vs Washington Post)

bias_fix = {
    "The Washington Post": "Lean Left",
    "New York Post": "Lean Right",
}

LRC_articles["bias"] = LRC_articles.apply(
    lambda row: bias_fix.get(row["outlet_name"], row["bias"]),
    axis=1
)

LRC_articles.isna().sum()

# %%
# Drop records with no content)
LRC_articles = LRC_articles.dropna()

# %%
LRC_articles.isna().sum()
# Out:
# outlet_name             0
# bias                    0
# date                    0
# content                 0
# content_preprocessed    0
# dtype: int64

# %%
LRC_articles.groupby("outlet_name").size()
# Out:
# outlet_name
# BBC News               16205
# Breitbart News         22361
# CNBC                   13343
# HuffPost               19373
# New York Post          13154
# Newsweek               32323
# Reuters                11144
# The Washington Post     9144
# Washington Times       10697
# dtype: int64

# %%
LRC_articles.to_parquet("LRC_articles.parquet", index=False)
