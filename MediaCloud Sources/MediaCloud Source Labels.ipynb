# %% [markdown]
# ### Creating Lists of sources by Political Popularity

# %%
import pandas as pd
import mediacloud
import datetime as dt

# %%
# Pull in CSVs
REP_sources = pd.read_csv('Collection-231013110-Rep Voters 2018.csv')
LEANREP_sources = pd.read_csv('Collection-231013109-LeanRep Voters 2018.csv')
SPLIT_sources = pd.read_csv('Collection-231013108-Split Voters 2018.csv')
LEANDEM_sources = pd.read_csv('Collection-231013089-LeanDem Voters 2018.csv')
DEM_sources = pd.read_csv('Collection-231013063-Dem Voters 2018.csv')

REP_sources['polarity'] = -1.0
LEANREP_sources['polarity'] = -0.5
SPLIT_sources['polarity'] = 0.0
LEANDEM_sources['polarity'] = 0.5
DEM_sources['polarity'] = 1.0

# Combine DFs
COMB_sources = pd.concat([REP_sources, LEANREP_sources, SPLIT_sources, LEANDEM_sources, DEM_sources],ignore_index=True)
#COMB_sources.head()

# Simplified DF
LABELED_sources = COMB_sources[['id','label','homepage','domain','polarity','media_type','stories_per_week','primary_language']].copy()
LABELED_sources.head()
# Out:
#     id             label                          homepage  \
# 0  101  Washington Times  https://www.washingtontimes.com/
# 1  109        Power Line    https://www.powerlineblog.com/
# 2  114   Right Wing News         http://rightwingnews.com/
# 3  117           Hot Air                 http://hotair.com
# 4  128          RedState         https://www.redstate.com/
#
#                 domain  polarity      media_type  stories_per_week  \
# 0  washingtontimes.com      -1.0    print_native             790.0
# 1    powerlineblog.com      -1.0             NaN               0.0
# 2    rightwingnews.com      -1.0             NaN               2.0
# 3           hotair.com      -1.0  digital_native             112.0
# 4         redstate.com      -1.0  digital_native             237.0
#
#   primary_language
# 0               en
# 1               en
# 2               en
# 3               en
# 4               en

# %% [markdown]
# ##### Evaluate Duplicate sources

# %%
# Create DF of domain counts
domain_counts = LABELED_sources['domain'].value_counts().reset_index()
domain_counts.columns = ['domain', 'occurrences']
domain_counts = domain_counts.sort_values('occurrences', ascending=False)
domain_counts['is_dupe_domain'] = domain_counts['occurrences'] > 1

# Add polarities column
domain_polarities = LABELED_sources.groupby('domain')['polarity'].apply(list).reset_index()
domain_polarities.columns = ['domain', 'polarities']

domain_counts = domain_counts.merge(domain_polarities, on='domain', how='left')

# summary DF of dupes
DUPE_domains = domain_counts[domain_counts['is_dupe_domain']]
DUPE_domains = DUPE_domains[['domain','occurrences','polarities']].sort_values('occurrences', ascending=False)

display(DUPE_domains)
# Out:
#                     domain  occurrences        polarities
# 0                   ap.org            3  [-0.5, 0.0, 1.0]
# 2       huffingtonpost.com            3   [0.0, 0.5, 1.0]
# 1             deadspin.com            3   [0.0, 0.5, 1.0]
# 32        baltimoresun.com            2        [0.0, 0.5]
# 31              boston.com            2        [0.5, 1.0]
# 30           nbcsports.com            2       [-0.5, 0.0]
# 29                 qns.com            2        [0.5, 1.0]
# 28          cincinnati.com            2       [-0.5, 0.0]
# 27       foreignpolicy.com            2        [0.0, 0.5]
# 18            suntimes.com            2        [0.0, 0.5]
# 25              gawker.com            2        [0.5, 1.0]
# 24           aljazeera.com            2        [0.5, 1.0]
# 23            observer.com            2        [0.0, 0.5]
# 22                wbur.org            2        [0.5, 1.0]
# 21            pennlive.com            2       [-0.5, 0.0]
# 20            theverge.com            2        [0.0, 0.5]
# 19        post-gazette.com            2        [0.0, 0.5]
# 26     phoenixnewtimes.com            2        [0.0, 0.5]
# 17             latimes.com            2        [0.0, 0.5]
# 16                  nj.com            2       [-0.5, 0.0]
# 15  nationalgeographic.com            2        [0.0, 0.5]
# 14          oregonlive.com            2       [-0.5, 0.5]
# 13             reuters.com            2        [0.0, 0.5]
# 12        seattletimes.com            2        [0.0, 0.5]
# 11             gizmodo.com            2        [0.0, 0.5]
# 10             foxnews.com            2      [-1.0, -0.5]
# 9               philly.com            2        [0.0, 0.5]
# 8          bostonglobe.com            2        [0.5, 1.0]
# 7          foxbusiness.com            2      [-1.0, -0.5]
# 6                wusa9.com            2        [0.0, 0.5]
# 5        wvgazettemail.com            2        [0.0, 0.5]
# 4                msnbc.com            2        [0.5, 1.0]
# 3                  npr.org            2        [0.5, 1.0]
# 33                time.com            2        [0.0, 0.5]

# %%
# Identify dupe counts - also confirmed labels/domains all match when there are dupes
DUP_counts = LABELED_sources.groupby(['label','domain','polarity']).size().reset_index(name='count')

DUP_counts = DUP_counts.sort_values('count', ascending=False)

DUP_summary = pd.DataFrame({
    'total_rows': [len(LABELED_sources)],
    'unique_domains': [LABELED_sources['domain'].nunique()],
    'domains_with_multiple_rows': [int(domain_counts['is_dupe_domain'].sum())],
    'exact_duplicate_rows': [int(DUP_counts.loc[DUP_counts['count'] > 1, 'count'].sum())]
})

display(DUP_summary)
# Out:
#    total_rows  unique_domains  domains_with_multiple_rows  \
# 0        1506            1469                          34
#
#    exact_duplicate_rows
# 0                     0

# %% [markdown]
# ##### Additional EDA

# %%
# Some additional EDA

print("Polarity Distribution:")
display(LABELED_sources['polarity'].value_counts().sort_index().reset_index())

print("Media Type Distribution:")
display(LABELED_sources['media_type'].value_counts().reset_index())

print("Language Distribution:")
display(LABELED_sources['primary_language'].value_counts().head(10).reset_index())

print("Stories per Week by Polarity:")
display(LABELED_sources.groupby('polarity')['stories_per_week'].describe())

print("Polarity vs Media Type:")
display(pd.crosstab(LABELED_sources['polarity'], LABELED_sources['media_type']))
# Out:
# Polarity Distribution:
#    polarity  count
# 0      -1.0    152
# 1      -0.5    254
# 2       0.0    526
# 3       0.5    378
# 4       1.0    196
# Media Type Distribution:
#         media_type  count
# 0     print_native    305
# 1  video_broadcast    244
# 2   digital_native    106
# 3            other      6
# Language Distribution:
#   primary_language  count
# 0               en   1306
# 1               es      3
# 2               zh      2
# 3               ar      2
# 4               ru      1
# 5               lb      1
# 6               ja      1
# 7               fa      1
# Stories per Week by Polarity:
#           count        mean         std  min    25%    50%     75%     max
# polarity
# -1.0      122.0   94.934426  154.777512  0.0   6.00   45.0  113.75   980.0
# -0.5      158.0  248.924051  389.106678  0.0  36.75  127.0  316.75  2501.0
#  0.0      371.0  315.350404  512.992178  0.0  40.00  158.0  377.00  5263.0
#  0.5      294.0  185.551020  444.615817  0.0  13.25   51.0  154.00  5263.0
#  1.0      163.0   55.055215  131.647127  0.0   3.00   17.0   48.50  1080.0
# Polarity vs Media Type:
# media_type  digital_native  other  print_native  video_broadcast
# polarity
# -1.0                    17      0             8                7
# -0.5                     6      1            59               99
#  0.0                    28      3           132              110
#  0.5                    37      1            81               21
#  1.0                    18      1            25                7

# %% [markdown]
# ##### Isolate top sources to test with Common Crawl

# %%
# Top sources of each split to look through the top stories per week and if they populate on common crawl
TOP_sources = (LABELED_sources
               .sort_values('stories_per_week', ascending=False)
               .groupby('polarity', group_keys=False)
               .head(5)
               .sort_values('polarity')
               .reset_index(drop=True))

display(TOP_sources)
# Out:
#         id                                  label  \
# 0   366487                    Conservative Review
# 1    19334                              Breitbart
# 2      101                       Washington Times
# 3   293059                 dennismichaellynch.com
# 4     1092                            Foxnews.com
# 5    18966                             reason.com
# 6    25701                           thesun.co.uk
# 7   717902                      daily.gazette.com
# 8    20120                                 nj.com
# 9    66979                               krdo.com
# 10    1089                                Reuters
# 11   32313                            thespec.com
# 12   22529                             philly.com
# 13   18482                          bloomberg.com
# 14       7                             nypost.com
# 15    1098                           newsweek.com
# 16   18203                             الجزيرة نت
# 17       1                         New York Times
# 18   22529                             philly.com
# 19    1089                                Reuters
# 20   22389                               Deadspin
# 21     314  The Huffington Post (old domain name)
# 22    1127                              Raw Story
# 23   21511                           Boston Globe
# 24    1096                                npr.org
#
#                                  homepage                  domain  polarity  \
# 0     https://www.conservativereview.com/  conservativereview.com      -1.0
# 1              https://www.breitbart.com/           breitbart.com      -1.0
# 2        https://www.washingtontimes.com/     washingtontimes.com      -1.0
# 3          http://dennismichaellynch.com/  dennismichaellynch.com      -1.0
# 4                 http://www.foxnews.com/             foxnews.com      -1.0
# 5                       http://reason.com              reason.com      -0.5
# 6   http://www.thesun.co.uk/sol/homepage/            thesun.co.uk      -0.5
# 7               http://daily.gazette.com/             gazette.com      -0.5
# 8                       http://www.nj.com                  nj.com      -0.5
# 9                    http://www.krdo.com/                krdo.com      -0.5
# 10                http://www.reuters.com/             reuters.com       0.0
# 11                 http://www.thespec.com             thespec.com       0.0
# 12                  http://www.philly.com              philly.com       0.0
# 13                   http://bloomberg.com           bloomberg.com       0.0
# 14                     https://nypost.com              nypost.com       0.0
# 15                   https://newsweek.com            newsweek.com       0.5
# 16                   http://aljazeera.net           aljazeera.net       0.5
# 17                     http://nytimes.com             nytimes.com       0.5
# 18                  http://www.philly.com              philly.com       0.5
# 19                http://www.reuters.com/             reuters.com       0.5
# 20                    http://deadspin.com            deadspin.com       1.0
# 21         http://www.huffingtonpost.com/      huffingtonpost.com       1.0
# 22                    http://rawstory.com            rawstory.com       1.0
# 23             http://www.bostonglobe.com         bostonglobe.com       1.0
# 24                    http://www.npr.org/                 npr.org       1.0
#
#          media_type  stories_per_week primary_language
# 0               NaN             491.0               en
# 1    digital_native             733.0               en
# 2      print_native             790.0               en
# 3               NaN             424.0               en
# 4   video_broadcast             980.0               en
# 5               NaN            2501.0               en
# 6               NaN            2496.0               en
# 7               NaN            2086.0               en
# 8    digital_native            1911.0               en
# 9   video_broadcast            1283.0               en
# 10            other            5263.0               en
# 11              NaN            3436.0               en
# 12              NaN            2996.0              NaN
# 13              NaN            2460.0               en
# 14     print_native            2287.0               en
# 15              NaN            1779.0               en
# 16  video_broadcast            1496.0               ar
# 17     print_native            2230.0               en
# 18              NaN            2996.0              NaN
# 19            other            5263.0               en
# 20   digital_native             745.0               en
# 21   digital_native             734.0               en
# 22   digital_native             551.0               en
# 23              NaN            1080.0               en
# 24  video_broadcast             406.0               en

# %%
# Export to csv 
LABELED_sources.to_csv('MediaCloudsources_Polarity.csv', index=False)
TOP_sources.to_csv('MediaCloudsources_TopsourcesToTest.csv', index=False)
